# %%
pip install newsapi-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\fexi\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from newsapi import NewsApiClient

newsapi = NewsApiClient(api_key='7f28dbaf34614d8aba94712f788a805b')

# %%
all_articles = newsapi.get_everything(q='England',from_param=)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-839fedeba871> in <module>
# ----> 1 all_articles = newsapi.get_everything(q='England',category="Finance")
#
# TypeError: get_everything() got an unexpected keyword argument 'category'

# %%
sources = newsapi.get_sources()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-2c9ec68dd5d0> in <module>
# ----> 1 sources = newsapi.get_category()
#
# AttributeError: 'NewsApiClient' object has no attribute 'get_category'

# %%
print(sources)
# Out:
# {'status': 'ok', 'sources': [{'id': 'abc-news', 'name': 'ABC News', 'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.', 'url': 'https://abcnews.go.com', 'category': 'general', 'language': 'en', 'country': 'us'}, {'id': 'abc-news-au', 'name': 'ABC News (AU)', 'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.", 'url': 'http://www.abc.net.au/news', 'category': 'general', 'language': 'en', 'country': 'au'}, {'id': 'aftenposten', 'name': 'Aftenposten', 'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.', 'url': 'https://www.aftenposten.no', 'category': 'general', 'language': 'no', 'country': 'no'}, {'id': 'al-jazeera-english', 'name': 'Al Jazeera English', 'description': 'News, analysis from the Middle East and worldwide, mult
# ...

# %%
print(all_articles
    )
# Out:
# {'status': 'ok', 'totalResults': 31702, 'articles': [{'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Grace Browne', 'title': 'The UK Government Wants to Sequence Your Baby’s Genome', 'description': 'Genomics England plans to test out a program that will offer whole genome sequencing to newborns—opening up a Pandora’s box of ethical concerns.', 'url': 'https://www.wired.com/story/whole-genome-sequencing-newborn-screening/', 'urlToImage': 'https://media.wired.com/photos/619eae1ff7172c8b76dfd533/191:100/w_1280,c_limit/Science-Newborn-Genome-Sequencing--1173295253.jpg', 'publishedAt': '2021-11-25T12:00:00Z', 'content': 'In November 2019, Matt Hancock, then the United Kingdoms health secretary, unveiled a lofty ambition: to sequence the genome of every baby in the country. It would usher in a genomic revolution, he s… [+3008 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': None, 'title': 'Stokes takes two wickets on England return', 'description': 'Ben Stokes
# ...

# %%
import json

# %%
print(all_articles.json())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-75f21ef52555> in <module>
# ----> 1 print(all_articles.json())
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
json_re = all_articles.json()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-d224cb47bea9> in <module>
# ----> 1 json_re = all_articles.json()
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
pretty = json.dump(all_articles.json(), indent=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-a3364cf46536> in <module>
# ----> 1 pretty = json.dump(all_articles.json(), indent=2)
#
# AttributeError: 'dict' object has no attribute 'json'

# %%
type(all_articles)
# Out:
# dict

# %%
json_re = json.loads(all_articles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-533c63f4299a> in <module>
# ----> 1 json_re = json.loads(all_articles)
#
# c:\users\fexi\appdata\local\programs\python\python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not dict

# %%
prety_output = list(all_articles.values())

# %%
print(prety_output)
# Out:
# ['ok', 31702, [{'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Grace Browne', 'title': 'The UK Government Wants to Sequence Your Baby’s Genome', 'description': 'Genomics England plans to test out a program that will offer whole genome sequencing to newborns—opening up a Pandora’s box of ethical concerns.', 'url': 'https://www.wired.com/story/whole-genome-sequencing-newborn-screening/', 'urlToImage': 'https://media.wired.com/photos/619eae1ff7172c8b76dfd533/191:100/w_1280,c_limit/Science-Newborn-Genome-Sequencing--1173295253.jpg', 'publishedAt': '2021-11-25T12:00:00Z', 'content': 'In November 2019, Matt Hancock, then the United Kingdoms health secretary, unveiled a lofty ambition: to sequence the genome of every baby in the country. It would usher in a genomic revolution, he s… [+3008 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': None, 'title': 'Stokes takes two wickets on England return', 'description': 'Ben Stokes makes his first appearance since July
# ...

# %%
all_articles[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-c05f01668aea> in <module>
# ----> 1 all_articles[0]
#
# KeyError: 0

# %%
print(all_articles['articles'][0]['title'])
# Out:
# The UK Government Wants to Sequence Your Baby’s Genome

# %%
m = all_articles['articles'][0]

values = [k['title'] for k in m if '*Covid*' in m]

# %%
type(all_articles['articles'][0])
# Out:
# dict

# %%
for m in [0] print(m);
# Out:
#   File "<ipython-input-35-07305a6a45b6>", line 1
#     for m in all_articles['articles'][0] print(m);
#                                          ^
# SyntaxError: invalid syntax

# %%
type(all_articles['articles'])
# Out:
# list

# %%
print(all_articles.values())
# Out:
# dict_values(['ok', 31702, [{'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Grace Browne', 'title': 'The UK Government Wants to Sequence Your Baby’s Genome', 'description': 'Genomics England plans to test out a program that will offer whole genome sequencing to newborns—opening up a Pandora’s box of ethical concerns.', 'url': 'https://www.wired.com/story/whole-genome-sequencing-newborn-screening/', 'urlToImage': 'https://media.wired.com/photos/619eae1ff7172c8b76dfd533/191:100/w_1280,c_limit/Science-Newborn-Genome-Sequencing--1173295253.jpg', 'publishedAt': '2021-11-25T12:00:00Z', 'content': 'In November 2019, Matt Hancock, then the United Kingdoms health secretary, unveiled a lofty ambition: to sequence the genome of every baby in the country. It would usher in a genomic revolution, he s… [+3008 chars]'}, {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': None, 'title': 'Stokes takes two wickets on England return', 'description': 'Ben Stokes makes his first appearanc
# ...

# %%
res = json.loads(all_articles['articles'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-031264160cba> in <module>
# ----> 1 res = json.loads(all_articles['articles'])
#
# c:\users\fexi\appdata\local\programs\python\python39\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337     else:
#     338         if not isinstance(s, (bytes, bytearray)):
# --> 339             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                             f'not {s.__class__.__name__}')
#     341         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
res = json.dumps(all_articles['articles'])

# %%
print(res)
# Out:
# [{"source": {"id": "wired", "name": "Wired"}, "author": "Grace Browne", "title": "The UK Government Wants to Sequence Your Baby\u2019s Genome", "description": "Genomics England plans to test out a program that will offer whole genome sequencing to newborns\u2014opening up a Pandora\u2019s box of ethical concerns.", "url": "https://www.wired.com/story/whole-genome-sequencing-newborn-screening/", "urlToImage": "https://media.wired.com/photos/619eae1ff7172c8b76dfd533/191:100/w_1280,c_limit/Science-Newborn-Genome-Sequencing--1173295253.jpg", "publishedAt": "2021-11-25T12:00:00Z", "content": "In November 2019, Matt Hancock, then the United Kingdoms health secretary, unveiled a lofty ambition: to sequence the genome of every baby in the country. It would usher in a genomic revolution, he s\u2026 [+3008 chars]"}, {"source": {"id": "bbc-news", "name": "BBC News"}, "author": null, "title": "Stokes takes two wickets on England return", "description": "Ben Stokes makes his first appearance sinc
# ...

# %%
print(res['source'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-0c8de17a64fe> in <module>
# ----> 1 print(res['source'])
#
# TypeError: string indices must be integers

# %%
all_articles['articles'].values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-137-1e2b7955d54c> in <module>
# ----> 1 all_articles['articles'].values()
#
# AttributeError: 'list' object has no attribute 'values'

# %%
new_value = [new_valuefor art in all_articles['articles']]
# Out:
#   File "<ipython-input-134-0b5826310278>", line 1
#     new_value = [for art in all_articles['articles']]
#                  ^
# SyntaxError: invalid syntax

# %%
hala =[]

for art in all_articles['articles']:
    hala.append(art['title'] + " -> " + art['url']);
    
print(hala)
# Out:
# ['The new plans for Covid booster jabs and how to get one – explained -> https://amp.theguardian.com/world/2021/dec/12/he-new-plans-for-covid-booster-jabs-and-how-to-get-one', "England's Broad and Anderson fit for Adelaide test, says Silverwood - Reuters -> https://www.reuters.com/world/uk/englands-broad-anderson-fit-adelaide-test-says-silverwood-2021-12-12/", 'Hunt launched to find ‘ghost children’ missing from schools in England -> https://amp.theguardian.com/society/2021/dec/12/hunt-launched-to-find-ghost-children-missing-from-schools-in-england', 'Mothers and babies at risk as vital health services in England stay shut -> https://amp.theguardian.com/society/2021/dec/12/mothers-and-babies-at-risk-as-vital-health-services-in-england-stay-shut', 'Weaknesses remain in Australia’s Ashes armour despite crushing win | Geoff Lemon -> https://amp.theguardian.com/sport/blog/2021/dec/12/cricket-australia-weaknesses-gabba-ashes-england', 'Jimmy Anderson and Stuart Broad ‘fit and ready’ for s
# ...

# %%
import datetime

# %%
today()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-4c38dcca567e> in <module>
# ----> 1 today()
#
# NameError: name 'today' is not defined

# %%
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2021, 12, 12)

# %%
date.today()
# Out:
# datetime.date(2021, 12, 12)

# %%
print(date.today())
# Out:
# 2021-12-12

# %%
day = datetime.datetime.now()

# %%
resulta = day.strftime("%y") 
resulta += "/" + day.strftime("%d")  
resulta += "/" + day.strftime("%m")

resulta

# %%
python-dateutil
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-78-0eb50fc04b44> in <module>
# ----> 1 python-dateutil
#
# NameError: name 'python' is not defined

# %%
date.now()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-2e7fbdeac7b8> in <module>
# ----> 1 date.now()
#
# NameError: name 'date' is not defined

# %%
all_articles = newsapi.get_everything(q='England',from_param=date.today(),to=yesterday,language='en')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-ca8a92bcbaee> in <module>
# ----> 1 all_articles = newsapi.get_everything(q='England',from_param=date.today(),to=yesterday,language='en')
#
# NameError: name 'yesterday' is not defined

# %%
today = date.today()

# %%
yesterday = today - timedelta(days = 1 )

# %%
from datetime import timedelta

# %%
all_articles = newsapi.get_everything(q='England',from_param=date.today(),to=yesterday,language='en')

# %%
response = json.dumps(all_articles['articles'])

# %%
print(response)
# Out:
# [{"source": {"id": null, "name": "The Guardian"}, "author": "Haroon Siddique and Denis Campbell", "title": "The new plans for Covid booster jabs and how to get one \u2013 explained", "description": "The government\u2019s ambitious rollout and what it means for adults in England<ul><li>Coronavirus \u2013 latest updates</li><li>See all our coronavirus coverage</li></ul>Ambitious plans have been announced for all adults in England to receive their Covid booster by th\u2026", "url": "https://amp.theguardian.com/world/2021/dec/12/he-new-plans-for-covid-booster-jabs-and-how-to-get-one", "urlToImage": "https://i.guim.co.uk/img/media/6ece73cdfeda0f57009e8094ffdaa185d032615f/0_361_6000_3600/master/6000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=d7ca742a9ad91c7de9a367fe834029bb", "publishedAt": "2021-12-12T20:42:57Z", "content": "Ambitious plans have bee
# ...

# %%
from newsapi import NewsApiClient
import json
from datetime import date
from datetime import timedelta

today = date.today()
yesterday = today - timedelta(days = 1 )




newsapi = NewsApiClient(api_key='7f28dbaf34614d8aba94712f788a805b')

all_articles = newsapi.get_everything(q='England',from_param=date.today(),to=yesterday,language='en')

response = json.dumps(all_articles['articles'])

print(response)
# Out:
# [{"source": {"id": null, "name": "The Guardian"}, "author": "Haroon Siddique and Denis Campbell", "title": "The new plans for Covid booster jabs and how to get one \u2013 explained", "description": "The government\u2019s ambitious rollout and what it means for adults in England<ul><li>Coronavirus \u2013 latest updates</li><li>See all our coronavirus coverage</li></ul>Ambitious plans have been announced for all adults in England to receive their Covid booster by th\u2026", "url": "https://amp.theguardian.com/world/2021/dec/12/he-new-plans-for-covid-booster-jabs-and-how-to-get-one", "urlToImage": "https://i.guim.co.uk/img/media/6ece73cdfeda0f57009e8094ffdaa185d032615f/0_361_6000_3600/master/6000.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=d7ca742a9ad91c7de9a367fe834029bb", "publishedAt": "2021-12-12T20:42:57Z", "content": "Ambitious plans have bee
# ...
